# %%
# importamos las librerías que necesitaremos

# Importar librería para trabajar con archivos JSON
# -----------------------------------------------------------------------
import json

# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd

import xml.etree.ElementTree as ET

# %% [markdown]
# ## Ej. 2

# %%
df = pd.read_csv("videogames.csv",  index_col = 0)

# %%
df
# Out:
#                                       name  \
# 0                               Spider-Man
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# ...

# %% [markdown]
# ## Ej. 3

# %%
df.head(10)
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
# 5     The Last of Us: Part II
# 6      Horizon Forbidden West
# 7              The Last of Us
# 8       Detroit: Become Human
# 9             Death Stranding
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
# 5  https://www.imdb.com/title/tt6298000/?ref_=adv...  2020.0           M
# 6  https://www.imdb.com/title/tt12496904/?ref_=ad...  2022.0           T
# ...

# %%
df.tail(1)
# Out:
#           name                                                url    year  \
# 20802  Cryptic  https://www.imdb.com/title/tt10964974/?ref_=ad...  2020.0
#
#       certificate  rating votes  \
# 20802         NaN     NaN   NaN
#
#                                                     plot  Action  Adventure  \
# 20802  Kidnapped by an insane man and dragged into a ...   False      False
#
#        Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  Thriller
# 20802   False  False   False    False    False   False      True

# %% [markdown]
# # Ej. 5

# %%
df.sample(15)
# Out:
#                                                     name  \
# 1674                                     Star Trek: Borg
# 4120                    Largo Winch: Empire Under Threat
# 5625           Warhammer 40,000: Dawn of War - Soulstorm
# 16413                   Disney Princess Royal Horse Show
# 7678                             Pocket Monsters Stadium
# 5952                                       Bump 'n' Jump
# 7795                                         Finest Hour
# 16562                  Brain Age: Concentration Training
# 8845                  Full Throttle: All-American Racing
# 5980                              Sonic Chrono Adventure
# 5259                                        Get medieval
# 13196                                    Tarr Chronicles
# 7608                                      Top Gear Rally
# 11890  Pale Spectrum: Part Two of the Book of Gray Magic
# 19246                             Simulacra: Pipe Dreams
#
# ...

# %% [markdown]
# ## Ej. 6

# %%
df.columns
# Out:
# Index(['name', 'url', 'year', 'certificate', 'rating', 'votes', 'plot',
#        'Action', 'Adventure', 'Comedy', 'Crime', 'Family', 'Fantasy',
#        'Mystery', 'Sci-Fi', 'Thriller'],
#       dtype='object')

# %% [markdown]
# ## Ej. 7

# %%
df.to_excel("videogames.xlsx")

# %%
df_videogames = pd.read_excel("videogames.xlsx", index_col = 0)

# %%
df_videogames

# %% [markdown]
# ## Ej. 8

# %%
df_videogames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20803 entries, 0 to 20802
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         20803 non-null  object
#  1   url          20803 non-null  object
#  2   year         20536 non-null  float64
#  3   certificate  7903 non-null   object
#  4   rating       11600 non-null  float64
#  5   votes        11600 non-null  object
#  6   plot         20803 non-null  object
#  7   Action       20803 non-null  bool
#  8   Adventure    20803 non-null  bool
#  9   Comedy       20803 non-null  bool
#  10  Crime        20803 non-null  bool
#  11  Family       20803 non-null  bool
#  12  Fantasy      20803 non-null  bool
#  13  Mystery      20803 non-null  bool
#  14  Sci-Fi       20803 non-null  bool
#  15  Thriller     20803 non-null  bool
# dtypes: bool(9), float64(2), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# # Ej. 9

# %%
df_videogames.isnull().sum()
# Out:
# name               0
# url                0
# year             267
# certificate    12900
# rating          9203
# votes           9203
# plot               0
# Action             0
# Adventure          0
# Comedy             0
# Crime              0
# Family             0
# Fantasy            0
# Mystery            0
# Sci-Fi             0
# Thriller           0
# dtype: int64

# %%
df_videogames.duplicated().sum()
# Out:
# 1

# %% [markdown]
# # Ej. 10

# %%
df_videogames.describe(include="object")
# Out:
#               name                                                url  \
# count        20803                                              20803
# unique       19714                                              20157
# top     Spider-Man  https://www.imdb.com/title/tt5807780/?ref_=adv...
# freq             9                                                  4
#
#        certificate  votes        plot
# count         7903  11600       20803
# unique          21   1905       11276
# top              T      7  Add a Plot
# freq          2474    318        8874

# %%
# El nombre que más aparece es Spiderman que son 9 veces
# La columna que tiene más valores unicos es url
# Las columnas name, url y plot tienen la misma cantidad de valores no nulos

# %% [markdown]
# ## Ej. 11

# %%
df.to_csv("videogames_para_todes.csv")
